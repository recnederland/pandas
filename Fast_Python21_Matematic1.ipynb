# %%
import pandas as pd

# %%
df = pd.read_csv('calisan_data.csv')

# %%
matris1 = df.values

# %%
df.head(3)
# Out:
#   Isimler Soyisimler TelefonTuru                    Departman     Sehir  \
# 0     ALİ   KANDEMİR       Sabit  Müşteri İlişkileri ve Satış   Kocaeli
# 1  MAHMUT      ÇEVİK       Sabit           Yazılım Geliştirme  İstanbul
# 2  MANSUR    ERKURAN    Vodafone           Yazılım Geliştirme    Ankara
#
#      DogumTarihi   Maas     Telefon                      mail
# 0  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com
# 1  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com
# 2  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com

# %%
kullaniciAdlari =[]
for i in range(0,2445):
    kullaniciAdlari.append(df.Isimler[i] + df.Soyisimler[i]) # kullaniciAdlarina adlari atalim

# %%
kullaniciAdlari
# Out:
# ['ALİKANDEMİR',
#  'MAHMUTÇEVİK',
#  'MANSURERKURAN',
#  'GAMZETÜTEN',
#  'MİRAÇÖZTÜRK',
#  'YÜCELYÜZBAŞIOĞLU',
#  'KUBİLAYVURAL',
#  'HAYATİYÜCEL',
#  'BEDRİYESÖNMEZ',
#  'BİRSENERTEKİN',
#  'SERDALDEDE',
#  'BÜNYAMİNUYANIK',
#  'ÖZGÜRASLAN',
#  'FERDİAKBULUT',
#  'REYHANORHON',
#  'İLHANUZ',
#  'GÜLŞAHYAVUZ',
#  'NALANERDEM',
#  'SEMİHKULAÇ',
#  'ERGÜNKAYA',
#  'FATİHSELVİ',
#  'ŞENAYAKPINAR',
#  'SERKANABACIOĞLU',
#  'EMREÇAY',
#  'BAHATTİNIŞIK',
#  'IRAZCAÖZER',
#  'HATİCEÖZDEMİR',
#  'BARIŞÖZTÜRK',
#  'REZANTAHTACI',
#  'FATİHBÜYÜKCAM',
#  'FUATKULAKSIZ',
#  'GÖKHANAKSEL',
#  'ORHANEROĞLU',
#  'MEHMETKARAKUM',
#  'EVRENDAL',
#  'OKTAYÖCAL',
#  'HARUNAYHAN',
#  'YAVUZYİĞİT',
#  'PINARYARBİL',
#  'MEHMETCANACANKATAN',
#  'UMUTGÜMÜŞAY',
#  'MESUDEMURT',
#  'HÜSEYİNHALHALLI',
#  'HAŞİMULUÖZ',
#  'EYYUPŞEYHANLI',
#  'MUSTAFAÇALIŞKANTÜRK',
#  'MUSTAFAYILMAZ',
#  'UFUKSARAÇOĞLU',
#  'AHMETSEZER',
#  'MEDİHADOĞAN',
#  'HASANDEMİR',
#  'KAMİLKAYAYURT',
#  'NEBİSÜRÜM',
#  'ÖZCANYAVAŞİ',
# ...

# %%
# df.drop(columns='kullanici_Adi', inplace=True)

# %%
df.insert(2, column='kullaniciAdi', value=kullaniciAdlari)

# %%
df.head(3)
# Out:
#   Isimler Soyisimler   kullaniciAdi TelefonTuru                    Departman  \
# 0     ALİ   KANDEMİR    ALİKANDEMİR       Sabit  Müşteri İlişkileri ve Satış
# 1  MAHMUT      ÇEVİK    MAHMUTÇEVİK       Sabit           Yazılım Geliştirme
# 2  MANSUR    ERKURAN  MANSURERKURAN    Vodafone           Yazılım Geliştirme
#
#       Sehir    DogumTarihi   Maas     Telefon                      mail
# 0   Kocaeli  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com
# 1  İstanbul  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com
# 2    Ankara  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com

# %%
for m in df.Maas:
    m += 1000
    print(m)
# Out:
# 10477
# 12331
# 12679
# 6206
# 9670
# 6875
# 6828
# 14114
# 10273
# 6361
# 6704
# 9004
# 8901
# 4546
# 5052
# 6769
# 9390
# 15490
# 6051
# 11187
# 6025
# 19123
# 19616
# 8511
# 13738
# 4063
# 5995
# 5011
# 5753
# 10039
# 6312
# 7918
# 5585
# 13791
# 6922
# 6566
# 10104
# 10117
# 10376
# 4173
# 6083
# 8499
# 8868
# 4851
# 13834
# 7715
# 12330
# 9939
# 7809
# 10196
# 19763
# 8345
# 9092
# 12583
# 6223
# 5442
# 10526
# 5789
# 8337
# 8767
# 6316
# 13502
# 4588
# 12148
# 9654
# 12496
# 7871
# 8542
# 17678
# 5333
# 8105
# 10583
# 9166
# 10162
# 15761
# 11565
# 10168
# 5428
# 5452
# 16390
# 6512
# 6249
# 8404
# 10063
# 8720
# 4139
# 14903
# 14728
# 7235
# 8435
# 7785
# 14823
# 8474
# 8438
# 6634
# 9823
# 4587
# 7244
# 5901
# 8973
# 8208
# 9826
# 8512
# 10236
# 14364
# 5167
# 12764
# 11364
# 12459
# 8243
# 5190
# 7685
# 6339
# 14536
# 8520
# 15874
# 10709
# 11391
# 4684
# 4027
# 5116
# 6121
# 8262
# 6773
# 12546
# 6501
# 8126
# 8226
# 12817
# 9940
# 4793
# 15034
# 8387
# 4207
# 7342
# 11791
# ...

# %%
# kalici olmasini istersek

# %%
for i in range(0, 2445):
    df.Maas[i] += 1000
# Out:
# C:\Users\recba\AppData\Local\Temp/ipykernel_19584/4218662991.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Maas[i] += 1000

# %%
df.head(6)
# Out:
#   Isimler   Soyisimler      kullaniciAdi   TelefonTuru  \
# 0     ALİ     KANDEMİR       ALİKANDEMİR         Sabit
# 1  MAHMUT        ÇEVİK       MAHMUTÇEVİK         Sabit
# 2  MANSUR      ERKURAN     MANSURERKURAN      Vodafone
# 3   GAMZE        TÜTEN        GAMZETÜTEN      Vodafone
# 4   MİRAÇ       ÖZTÜRK       MİRAÇÖZTÜRK  Türk Telekom
# 5   YÜCEL  YÜZBAŞIOĞLU  YÜCELYÜZBAŞIOĞLU      Vodafone
#
#                      Departman     Sehir      DogumTarihi     Maas  \
# 0  Müşteri İlişkileri ve Satış   Kocaeli    22 Nisan 1985  12477.0
# 1           Yazılım Geliştirme  İstanbul    02 Mayıs 1979  14331.0
# 2           Yazılım Geliştirme    Ankara    02 Kasım 1979  14679.0
# 3           Yazılım Geliştirme     Bursa    03 Şubat 1987      NaN
# 4           Yazılım Geliştirme  İstanbul     22 Ekim 1987      NaN
# 5           Yazılım Geliştirme  İstanbul  11 Haziran 1987      NaN
#
#       Telefon                          mail
# 0  2625462003        kandemirali@yandex.com
# ...

# %%
# add fnksiyonu ile yapalim

# %%
df['Maas'].add(1000).head()
# Out:
# 0    11477
# 1    13331
# 2    13679
# 3     7206
# 4    10670
# Name: Maas, dtype: int64

# %%
df['Maas'].fillna('10000', inplace=True)

# %%
# df['Maas'] = df['Maas'].add(1000).head(3)

# %%
df.head(10)
# Out:
#    Isimler   Soyisimler      kullaniciAdi   TelefonTuru  \
# 0      ALİ     KANDEMİR       ALİKANDEMİR         Sabit
# 1   MAHMUT        ÇEVİK       MAHMUTÇEVİK         Sabit
# 2   MANSUR      ERKURAN     MANSURERKURAN      Vodafone
# 3    GAMZE        TÜTEN        GAMZETÜTEN      Vodafone
# 4    MİRAÇ       ÖZTÜRK       MİRAÇÖZTÜRK  Türk Telekom
# 5    YÜCEL  YÜZBAŞIOĞLU  YÜCELYÜZBAŞIOĞLU      Vodafone
# 6  KUBİLAY        VURAL      KUBİLAYVURAL  Türk Telekom
# 7   HAYATİ        YÜCEL       HAYATİYÜCEL  Türk Telekom
# 8  BEDRİYE       SÖNMEZ     BEDRİYESÖNMEZ  Türk Telekom
# 9   BİRSEN      ERTEKİN     BİRSENERTEKİN  Türk Telekom
#
#                      Departman     Sehir      DogumTarihi     Maas  \
# 0  Müşteri İlişkileri ve Satış   Kocaeli    22 Nisan 1985  13477.0
# 1           Yazılım Geliştirme  İstanbul    02 Mayıs 1979  15331.0
# 2           Yazılım Geliştirme    Ankara    02 Kasım 1979  15679.0
# 3           Yazılım Geliştirme     Bursa    03 Şubat 1987    10000
# ...

# %%
# Maaslara %20 zam yapalim

# %%
df.shape
# Out:
# (2445, 10)

# %%
df['Maas'] = df['Maas'].mul(1.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
df['Maas'] = df['Maas'].div(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %% [markdown]
# # value_counts()

# %%
df['Departman'].value_counts()
# Out:
# Yazılım Geliştirme             1459
# Müşteri İlişkileri ve Satış     372
# Mali İşler                      364
# İnsan Kaynakları                174
# Yönetim                          76
# Name: Departman, dtype: int64

# %%
df['Departman'].value_counts().sum()
# Out:
# 2445

# %%
df['TelefonTuru'].value_counts()
# Out:
# Türk Telekom    1109
# Vodafone         863
# Sabit            253
# Türkcell         220
# Name: TelefonTuru, dtype: int64
