# %%
import numpy as np

# %%
import pandas as pd

# %%
from numpy import genfromtxt

# %%
from IPython.display import Image

# %%
Image(filename= "C:\\Users\\recba\\JUPYTER\\5Saatte_pythonPandas\\DataType.png" )

# %%
Image(filename= "C:\\Users\\recba\\JUPYTER\\5Saatte_pythonPandas\\DataType2.png" )

# %%
Image(filename= "C:\\Users\\recba\\JUPYTER\\5Saatte_pythonPandas\\DataOfValue.png" )

# %%
# kucuk buyuk harf onemlidir
#

# %%
# Listeler
calisanlar = ['ali', 'veli', 'kirkdokuz', 'elli']

# %%
calisanlar
# Out:
# ['ali', 'veli', 'kirkdokuz', 'elli']

# %%
# sozluk / dictionary
dict_1 = {'ali':1000, 'veli':2000, 'kirkdokuz':49, 'elli': 50}

# %%
dict_1
# Out:
# {'ali': 1000, 'veli': 2000, 'kirkdokuz': 49, 'elli': 50}

# %%
dict_1['ali']
# Out:
# 1000
