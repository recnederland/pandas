# %%
import pandas as pd

# %%
df = pd.read_csv('calisan_data.csv')

# %%
matris1 = df.values

# %%
df
# Out:
#      Isimler     Soyisimler   TelefonTuru                    Departman  \
# 0        ALİ       KANDEMİR         Sabit  Müşteri İlişkileri ve Satış
# 1     MAHMUT          ÇEVİK         Sabit           Yazılım Geliştirme
# 2     MANSUR        ERKURAN      Vodafone           Yazılım Geliştirme
# 3      GAMZE          TÜTEN      Vodafone           Yazılım Geliştirme
# 4      MİRAÇ         ÖZTÜRK  Türk Telekom           Yazılım Geliştirme
# ...      ...            ...           ...                          ...
# 2440  YILMAZ         YAZICI      Vodafone           Yazılım Geliştirme
# 2441  ZEYNEP     DOĞANGÜZEL  Türk Telekom           Yazılım Geliştirme
# 2442   CANER         AKKAYA  Türk Telekom           Yazılım Geliştirme
# 2443  VOLKAN  FEYZULLAHOĞLU  Türk Telekom           Yazılım Geliştirme
# 2444    EMRE          ŞAHİN      Vodafone           Yazılım Geliştirme
#
#          Sehir     DogumTarihi   Maas     Telefon  \
# 0      Kocaeli   22 Nisan 1985   9477  2625462003
# ...

# %%
matris1
# Out:
# array([['ALİ', 'KANDEMİR', 'Sabit', ..., 9477, 2625462003,
#         'kandemirali@yandex.com'],
#        ['MAHMUT', 'ÇEVİK', 'Sabit', ..., 11331, 2128804662,
#         'mahmut.çevik@yandex.com'],
#        ['MANSUR', 'ERKURAN', 'Vodafone', ..., 11679, 5488439920,
#         'mansur.erkuran@gmail.com'],
#        ...,
#        ['CANER', 'AKKAYA', 'Türk Telekom', ..., 8716, 5533969681,
#         'akkaya.caner@yandex.com'],
#        ['VOLKAN', 'FEYZULLAHOĞLU', 'Türk Telekom', ..., 9408, 5069462233,
#         'feyzullahoğlu.volkan@yahoo.com'],
#        ['EMRE', 'ŞAHİN', 'Vodafone', ..., 14493, 5415697256,
#         'emre.şahin@yandex.com']], dtype=object)

# %%
df.Maas
# Out:
# 0        9477
# 1       11331
# 2       11679
# 3        5206
# 4        8670
#         ...
# 2440    12593
# 2441     6021
# 2442     8716
# 2443     9408
# 2444    14493
# Name: Maas, Length: 2445, dtype: int64

# %%
df['Maas']  # ozellikle iki ve fazlasi ise kelime sayisi bu yol tercih edilir
# Out:
# 0        9477
# 1       11331
# 2       11679
# 3        5206
# 4        8670
#         ...
# 2440    12593
# 2441     6021
# 2442     8716
# 2443     9408
# 2444    14493
# Name: Maas, Length: 2445, dtype: int64

# %%
df.rename(columns={'DogumTarihi':'Dagum Tatrihi'})
# Out:
#      Isimler     Soyisimler   TelefonTuru                    Departman  \
# 0        ALİ       KANDEMİR         Sabit  Müşteri İlişkileri ve Satış
# 1     MAHMUT          ÇEVİK         Sabit           Yazılım Geliştirme
# 2     MANSUR        ERKURAN      Vodafone           Yazılım Geliştirme
# 3      GAMZE          TÜTEN      Vodafone           Yazılım Geliştirme
# 4      MİRAÇ         ÖZTÜRK  Türk Telekom           Yazılım Geliştirme
# ...      ...            ...           ...                          ...
# 2440  YILMAZ         YAZICI      Vodafone           Yazılım Geliştirme
# 2441  ZEYNEP     DOĞANGÜZEL  Türk Telekom           Yazılım Geliştirme
# 2442   CANER         AKKAYA  Türk Telekom           Yazılım Geliştirme
# 2443  VOLKAN  FEYZULLAHOĞLU  Türk Telekom           Yazılım Geliştirme
# 2444    EMRE          ŞAHİN      Vodafone           Yazılım Geliştirme
#
#          Sehir   Dagum Tatrihi   Maas     Telefon  \
# 0      Kocaeli   22 Nisan 1985   9477  2625462003
# ...

# %%
df
# Out:
#      Isimler     Soyisimler   TelefonTuru                    Departman  \
# 0        ALİ       KANDEMİR         Sabit  Müşteri İlişkileri ve Satış
# 1     MAHMUT          ÇEVİK         Sabit           Yazılım Geliştirme
# 2     MANSUR        ERKURAN      Vodafone           Yazılım Geliştirme
# 3      GAMZE          TÜTEN      Vodafone           Yazılım Geliştirme
# 4      MİRAÇ         ÖZTÜRK  Türk Telekom           Yazılım Geliştirme
# ...      ...            ...           ...                          ...
# 2440  YILMAZ         YAZICI      Vodafone           Yazılım Geliştirme
# 2441  ZEYNEP     DOĞANGÜZEL  Türk Telekom           Yazılım Geliştirme
# 2442   CANER         AKKAYA  Türk Telekom           Yazılım Geliştirme
# 2443  VOLKAN  FEYZULLAHOĞLU  Türk Telekom           Yazılım Geliştirme
# 2444    EMRE          ŞAHİN      Vodafone           Yazılım Geliştirme
#
#          Sehir     DogumTarihi   Maas     Telefon  \
# 0      Kocaeli   22 Nisan 1985   9477  2625462003
# ...

# %%
# kalici degisiklik yapalim inplace=Truce

# %%
df.rename(columns={'Dagum Tatrihi':'Dogum Tarihi'}, inplace=True)

# %%
df
# Out:
#      Isimler     Soyisimler   TelefonTuru                    Departman  \
# 0        ALİ       KANDEMİR         Sabit  Müşteri İlişkileri ve Satış
# 1     MAHMUT          ÇEVİK         Sabit           Yazılım Geliştirme
# 2     MANSUR        ERKURAN      Vodafone           Yazılım Geliştirme
# 3      GAMZE          TÜTEN      Vodafone           Yazılım Geliştirme
# 4      MİRAÇ         ÖZTÜRK  Türk Telekom           Yazılım Geliştirme
# ...      ...            ...           ...                          ...
# 2440  YILMAZ         YAZICI      Vodafone           Yazılım Geliştirme
# 2441  ZEYNEP     DOĞANGÜZEL  Türk Telekom           Yazılım Geliştirme
# 2442   CANER         AKKAYA  Türk Telekom           Yazılım Geliştirme
# 2443  VOLKAN  FEYZULLAHOĞLU  Türk Telekom           Yazılım Geliştirme
# 2444    EMRE          ŞAHİN      Vodafone           Yazılım Geliştirme
#
#          Sehir    Dogum Tarihi   Maas     Telefon  \
# 0      Kocaeli   22 Nisan 1985   9477  2625462003
# ...

# %%
df['Dogum Tarihi']
# Out:
# 0        22 Nisan 1985
# 1        02 Mayıs 1979
# 2        02 Kasım 1979
# 3        03 Şubat 1987
# 4         22 Ekim 1987
#              ...
# 2440    09 Aralık 1975
# 2441     22 Mayıs 1986
# 2442     07 Kasım 1983
# 2443    09 Temmuz 1984
# 2444    16 Temmuz 1978
# Name: Dogum Tarihi, Length: 2445, dtype: object

# %%
df[['Maas','Telefon']] # DataFrame doner ikiden fazlasi
# Out:
#        Maas     Telefon
# 0      9477  2625462003
# 1     11331  2128804662
# 2     11679  5488439920
# 3      5206  5427560798
# 4      8670  5544899572
# ...     ...         ...
# 2440  12593  5443005679
# 2441   6021  5533689407
# 2442   8716  5533969681
# 2443   9408  5069462233
# 2444  14493  5415697256
#
# [2445 rows x 2 columns]

# %%
# CHALENGS

# %%
df
# Out:
#      Isimler     Soyisimler   TelefonTuru                    Departman  \
# 0        ALİ       KANDEMİR         Sabit  Müşteri İlişkileri ve Satış
# 1     MAHMUT          ÇEVİK         Sabit           Yazılım Geliştirme
# 2     MANSUR        ERKURAN      Vodafone           Yazılım Geliştirme
# 3      GAMZE          TÜTEN      Vodafone           Yazılım Geliştirme
# 4      MİRAÇ         ÖZTÜRK  Türk Telekom           Yazılım Geliştirme
# ...      ...            ...           ...                          ...
# 2440  YILMAZ         YAZICI      Vodafone           Yazılım Geliştirme
# 2441  ZEYNEP     DOĞANGÜZEL  Türk Telekom           Yazılım Geliştirme
# 2442   CANER         AKKAYA  Türk Telekom           Yazılım Geliştirme
# 2443  VOLKAN  FEYZULLAHOĞLU  Türk Telekom           Yazılım Geliştirme
# 2444    EMRE          ŞAHİN      Vodafone           Yazılım Geliştirme
#
#          Sehir    Dogum Tarihi   Maas     Telefon  \
# 0      Kocaeli   22 Nisan 1985   9477  2625462003
# ...

# %%
1- Sirketin odedigi toplam maas nedir?
2- Her calisana ad ve soyadini birlestirip bir kullanici adi verelim recbay gibi

# %%
# 1- Sirketin odedigi toplam maas nedir?

# %%
toplamMaas = 0
for m in df.Maas:
    toplamMaas += m # 1. for dongusu ile

# %%
toplamMaas
# Out:
# 19904721

# %%
df.Maas.sum() # 2. method yolu kisa
# Out:
# 19904721

# %%
# 2- Her calisana ad ve soyadini birlestirip bir kullanici adi verelim recbay gibi

# %%
df.sum() # burda isimler yanyana yazilmis oldu
# Out:
# Isimler         ALİMAHMUTMANSURGAMZEMİRAÇYÜCELKUBİLAYHAYATİBED...
# Soyisimler      KANDEMİRÇEVİKERKURANTÜTENÖZTÜRKYÜZBAŞIOĞLUVURA...
# TelefonTuru     SabitSabitVodafoneVodafoneTürk TelekomVodafone...
# Departman       Müşteri İlişkileri ve SatışYazılım GeliştirmeY...
# Sehir           KocaeliİstanbulAnkaraBursaİstanbulİstanbulİsta...
# Dogum Tarihi    22 Nisan 198502 Mayıs 197902 Kasım 197903 Şuba...
# Maas                                                     19904721
# Telefon                                            12479154737113
# mail            kandemirali@yandex.commahmut.çevik@yandex.comm...
# dtype: object

# %%
kullaniciDF = df[['Isimler','Soyisimler']]

# %%
kullaniciDF.sum(axis='columns')
# Out:
# 0               ALİKANDEMİR
# 1               MAHMUTÇEVİK
# 2             MANSURERKURAN
# 3                GAMZETÜTEN
# 4               MİRAÇÖZTÜRK
#                ...
# 2440           YILMAZYAZICI
# 2441       ZEYNEPDOĞANGÜZEL
# 2442            CANERAKKAYA
# 2443    VOLKANFEYZULLAHOĞLU
# 2444              EMREŞAHİN
# Length: 2445, dtype: object

# %%
kullaniciAdlari =[]
for i in range(0,2445):
    print(df.Isimler[i] + df.Soyisimler[i]) # aradigimiz kombinasyon bu
# Out:
# ALİKANDEMİR
# MAHMUTÇEVİK
# MANSURERKURAN
# GAMZETÜTEN
# MİRAÇÖZTÜRK
# YÜCELYÜZBAŞIOĞLU
# KUBİLAYVURAL
# HAYATİYÜCEL
# BEDRİYESÖNMEZ
# BİRSENERTEKİN
# SERDALDEDE
# BÜNYAMİNUYANIK
# ÖZGÜRASLAN
# FERDİAKBULUT
# REYHANORHON
# İLHANUZ
# GÜLŞAHYAVUZ
# NALANERDEM
# SEMİHKULAÇ
# ERGÜNKAYA
# FATİHSELVİ
# ŞENAYAKPINAR
# SERKANABACIOĞLU
# EMREÇAY
# BAHATTİNIŞIK
# IRAZCAÖZER
# HATİCEÖZDEMİR
# BARIŞÖZTÜRK
# REZANTAHTACI
# FATİHBÜYÜKCAM
# FUATKULAKSIZ
# GÖKHANAKSEL
# ORHANEROĞLU
# MEHMETKARAKUM
# EVRENDAL
# OKTAYÖCAL
# HARUNAYHAN
# YAVUZYİĞİT
# PINARYARBİL
# MEHMETCANACANKATAN
# UMUTGÜMÜŞAY
# MESUDEMURT
# HÜSEYİNHALHALLI
# HAŞİMULUÖZ
# EYYUPŞEYHANLI
# MUSTAFAÇALIŞKANTÜRK
# MUSTAFAYILMAZ
# UFUKSARAÇOĞLU
# AHMETSEZER
# MEDİHADOĞAN
# HASANDEMİR
# KAMİLKAYAYURT
# NEBİSÜRÜM
# ÖZCANYAVAŞİ
# NAGİHANTURGUT
# CERENŞEN
# SERKANBARBAROS
# HASANALDİNÇ
# YUSUFTEKİN
# ÇETİNGÜLŞAN
# TARKANKÜFECİLER
# MERALALMACIOĞLU
# ERGÜNÇİLDİR
# KENANTÜRKDOĞAN
# URALKAYA
# YAHYAÖNER
# BENGÜŞELİMAN
# FATİHYAMAN
# DİLEKATİK
# ...

# %%
kullaniciAdlari =[]
for i in range(0,2445):
    kullaniciAdlari.append(df.Isimler[i] + df.Soyisimler[i]) # kullaniciAdlarina adlari atalim

# %%
kullaniciAdlari
# Out:
# ['ALİKANDEMİR',
#  'MAHMUTÇEVİK',
#  'MANSURERKURAN',
#  'GAMZETÜTEN',
#  'MİRAÇÖZTÜRK',
#  'YÜCELYÜZBAŞIOĞLU',
#  'KUBİLAYVURAL',
#  'HAYATİYÜCEL',
#  'BEDRİYESÖNMEZ',
#  'BİRSENERTEKİN',
#  'SERDALDEDE',
#  'BÜNYAMİNUYANIK',
#  'ÖZGÜRASLAN',
#  'FERDİAKBULUT',
#  'REYHANORHON',
#  'İLHANUZ',
#  'GÜLŞAHYAVUZ',
#  'NALANERDEM',
#  'SEMİHKULAÇ',
#  'ERGÜNKAYA',
#  'FATİHSELVİ',
#  'ŞENAYAKPINAR',
#  'SERKANABACIOĞLU',
#  'EMREÇAY',
#  'BAHATTİNIŞIK',
#  'IRAZCAÖZER',
#  'HATİCEÖZDEMİR',
#  'BARIŞÖZTÜRK',
#  'REZANTAHTACI',
#  'FATİHBÜYÜKCAM',
#  'FUATKULAKSIZ',
#  'GÖKHANAKSEL',
#  'ORHANEROĞLU',
#  'MEHMETKARAKUM',
#  'EVRENDAL',
#  'OKTAYÖCAL',
#  'HARUNAYHAN',
#  'YAVUZYİĞİT',
#  'PINARYARBİL',
#  'MEHMETCANACANKATAN',
#  'UMUTGÜMÜŞAY',
#  'MESUDEMURT',
#  'HÜSEYİNHALHALLI',
#  'HAŞİMULUÖZ',
#  'EYYUPŞEYHANLI',
#  'MUSTAFAÇALIŞKANTÜRK',
#  'MUSTAFAYILMAZ',
#  'UFUKSARAÇOĞLU',
#  'AHMETSEZER',
#  'MEDİHADOĞAN',
#  'HASANDEMİR',
#  'KAMİLKAYAYURT',
#  'NEBİSÜRÜM',
#  'ÖZCANYAVAŞİ',
# ...

# %%
# Onceden olmayan bir sutunu DataFrame'e ekleyelim
# kullaniciAdlari'na zaten Isimler ve Soyisimleri eklemistik, onu kullanalim

# %%
df['kullaniciAdi'] = kullaniciAdlari

# %%
df.head(3)
# Out:
#   Isimler Soyisimler TelefonTuru                    Departman     Sehir  \
# 0     ALİ   KANDEMİR       Sabit  Müşteri İlişkileri ve Satış   Kocaeli
# 1  MAHMUT      ÇEVİK       Sabit           Yazılım Geliştirme  İstanbul
# 2  MANSUR    ERKURAN    Vodafone           Yazılım Geliştirme    Ankara
#
#     Dogum Tarihi   Maas     Telefon                      mail   kullaniciAdi
# 0  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com    ALİKANDEMİR
# 1  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com    MAHMUTÇEVİK
# 2  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com  MANSURERKURAN

# %%
# artik son kolon kullanici adi oldu

# %%
# kolon nasil silinir drop ile

# %%
df.drop(columns='kullaniciAdi').head(3)
# Out:
#   Isimler Soyisimler TelefonTuru                    Departman     Sehir  \
# 0     ALİ   KANDEMİR       Sabit  Müşteri İlişkileri ve Satış   Kocaeli
# 1  MAHMUT      ÇEVİK       Sabit           Yazılım Geliştirme  İstanbul
# 2  MANSUR    ERKURAN    Vodafone           Yazılım Geliştirme    Ankara
#
#     Dogum Tarihi   Maas     Telefon                      mail
# 0  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com
# 1  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com
# 2  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com

# %%
df.head(3)
# Out:
#   Isimler Soyisimler TelefonTuru                    Departman     Sehir  \
# 0     ALİ   KANDEMİR       Sabit  Müşteri İlişkileri ve Satış   Kocaeli
# 1  MAHMUT      ÇEVİK       Sabit           Yazılım Geliştirme  İstanbul
# 2  MANSUR    ERKURAN    Vodafone           Yazılım Geliştirme    Ankara
#
#     Dogum Tarihi   Maas     Telefon                      mail   kullaniciAdi
# 0  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com    ALİKANDEMİR
# 1  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com    MAHMUTÇEVİK
# 2  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com  MANSURERKURAN

# %%
# kalici silmek icin inplace kullanalim

# %%
df.drop(columns='kullanici_Adi', inplace=True)

# %%
df.head(3)
# Out:
#   Isimler Soyisimler TelefonTuru                    Departman     Sehir  \
# 0     ALİ   KANDEMİR       Sabit  Müşteri İlişkileri ve Satış   Kocaeli
# 1  MAHMUT      ÇEVİK       Sabit           Yazılım Geliştirme  İstanbul
# 2  MANSUR    ERKURAN    Vodafone           Yazılım Geliştirme    Ankara
#
#     Dogum Tarihi   Maas     Telefon                      mail
# 0  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com
# 1  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com
# 2  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com

# %%
# kullaniciAdi kolonunu 2. indexe ekleyelim, INSERT kullanalim

# %%
df.insert(2, column='kullaniciAdi', value=kullaniciAdlari)

# %%
df.head(3)
# Out:
#   Isimler Soyisimler   kullaniciAdi TelefonTuru                    Departman  \
# 0     ALİ   KANDEMİR    ALİKANDEMİR       Sabit  Müşteri İlişkileri ve Satış
# 1  MAHMUT      ÇEVİK    MAHMUTÇEVİK       Sabit           Yazılım Geliştirme
# 2  MANSUR    ERKURAN  MANSURERKURAN    Vodafone           Yazılım Geliştirme
#
#       Sehir   Dogum Tarihi   Maas     Telefon                      mail
# 0   Kocaeli  22 Nisan 1985   9477  2625462003    kandemirali@yandex.com
# 1  İstanbul  02 Mayıs 1979  11331  2128804662   mahmut.çevik@yandex.com
# 2    Ankara  02 Kasım 1979  11679  5488439920  mansur.erkuran@gmail.com
