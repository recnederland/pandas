# %%
import pandas as pd

# %%
netflix = pd.read_csv('netflix.csv')

# %%
netflix.head()
# Out:
#      sov_no     tipi                                   baslik  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    yonetmen  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                            oyuncular  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                        ulke     eklenme_tarihi  cikis_tarihi  \
# ...

# %%
# cikis tarihine gore siralama yapalim ve ilk cikanlar yukarida olsun

# %% [markdown]
# netflix.sort_values(
#     by,
#     axis: 'Axis' = 0,
#     ascending=True,
#     inplace: 'bool' = False,
#     kind: 'str' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc' = None,
# )

# %%
netflix.sort_values('cikis_tarihi').head()
# Out:
#         sov_no     tipi                                         baslik  \
# 4292  81030762  TV Show              Pioneers: First Women Filmmakers*
# 2011  60027945    Movie                                 Prelude to War
# 2013  60027942    Movie                           The Battle of Midway
# 2022  80119186    Movie  Undercover: How to Operate Behind Enemy Lines
# 2023  70013050    Movie             Why We Fight: The Battle of Russia
#
#                          yonetmen                  oyuncular           ulke  \
# 4292                          NaN                        NaN            NaN
# 2011                  Frank Capra                        NaN  United States
# 2013                    John Ford  Henry Fonda, Jane Darwell  United States
# 2022                    John Ford                        NaN  United States
# 2023  Frank Capra, Anatole Litvak                        NaN  United States
#
#          eklenme_tarihi  cikis_tarihi      sure  \
# ...

# %%
netflix.sort_values('cikis_tarihi', ascending=False).head()
# Out:
#         sov_no     tipi                         baslik  \
# 3467  81011449  TV Show                 Medical Police
# 3249  81006825    Movie  All the Freckles in the World
# 3220  80997687  TV Show                        Dracula
# 3427  81060049    Movie     Leslie Jones: Time Machine
# 3436  80239306  TV Show     The Healing Powers of Dude
#
#                        yonetmen  \
# 3467                        NaN
# 3249               Yibrán Asuad
# 3220                        NaN
# 3427  David Benioff, D.B. Weiss
# 3436                        NaN
#
#                                               oyuncular            ulke  \
# 3467  Erinn Hayes, Rob Huebel, Malin Akerman, Rob Co...   United States
# 3249  Hánssel Casillas, Loreto Peralta, Andrea Sutto...          Mexico
# 3220            Claes Bang, Dolly Wells, John Heffernan  United Kingdom
# 3427                                       Leslie Jones   United States
# ...

# %%
netflix.sort_values('ulke', ascending=True).head()
# Out:
#         sov_no     tipi                   baslik  \
# 532   81105406  TV Show  Monzón: A Knockout Blow
# 6210  80239700  TV Show              Psiconautas
# 4075  80156767    Movie         La Última Fiesta
# 398   80190990    Movie      Todo Sobre El Asado
# 4422  80142140    Movie                Daemonium
#
#                            yonetmen  \
# 532                             NaN
# 6210                            NaN
# 4075  Leandro Mark, Nicolás Silbert
# 398     Mariano Cohn, Gastón Duprat
# 4422                    Pablo Parés
#
#                                               oyuncular       ulke  \
# 532   Jorge Román, Mauricio Paniagua, Carla Quevedo,...  Argentina
# 6210  Guillermo Toledo, Gabriel Goity, Florencia Peñ...  Argentina
# 4075  Nicolás Vázquez, Alan Sabbagh, Benjamín Amadeo...  Argentina
# 398                                    El Negro Álvarez  Argentina
# 4422  Walter Cornás, Dany Casco, Caro Angus, Rocío R...  Argentina
#
# ...

# %%
netflix.sort_index().head()
# Out:
#      sov_no     tipi                                   baslik  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    yonetmen  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                            oyuncular  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                        ulke     eklenme_tarihi  cikis_tarihi  \
# ...
